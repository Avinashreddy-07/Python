# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# Fundamental Types

# %% [markdown]
# Intergers

# %%
9
# Out:
# 9

# %%
a = 7
b=3
print(a+b)
# Out:
# 10

# %%
a = 7
print("abc"+a) #Error will Occur because'a=7' its a Integer, Cannot concat with String.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 a = 7
# ----> 2 print("abc"+a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = 7
print("abc"+ str(a))
# Out:
# abc7

# %% [markdown]
# Floats

# %%
x=1.342
x
# Out:
# 1.342

# %%
x=5
type(x)
# Out:
# int

# %%
y=3.52
type(y)
# Out:
# float

# %%
z=x+y
type(z)
# Out:
# float

# %% [markdown]
# Boolean

# %%
a1=True
a1
# Out:
# True

# %%
b1=False
b1
# Out:
# False

# %% [markdown]
# Strings

# %%
name1 = """ "My" name is Jupyter's notebook """
print(name1)
# Out:
#  "My" name is Jupyter's notebook

# %% [markdown]
# Complex

# %%
j = 1.0 - 2.0j
j
# Out:
# (1-2j)

# %%
j = 1.0 - 2.0j
type(j)
# Out:
# complex

# %%
print(j.real, j.imag) #j.real_number, j.imaginary_number
# Out:
# 1.0 -2.0

# %% [markdown]
# Variables

# %%
number = 10
number = 15
number
# Out:
# 15

# %%
# Dynamic Typing
''' python is dynamically typed-
you dont declare variable types(like int, string, float)
type is decided at runtime, based on the value you assign.'''

# %%
print("str"+str(1))
# Out:
# str1

# %%
#Operators in python
a = 10
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b) #floor division
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000
# 3

# %%
# Comparison operations
a= 5
b= 7
print(a==b)
print(a != b)
print(a < b)
print(a > b)
print(a <= b)
print(a >= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
# Logical Operations

x = True
y = False
print(x and y)
print(x or y)
print(not y)
# Out:
# False
# True
# True

# %%
# assignment Operations
x = 5  # ----> x=5
x = +5  # ----> x = +5
x = -5  # ----> x = -5

x += 5 #---> x = x+5
x -= 5 #---> x = x-5
x *= 3 #---> x = x*3

# %%
name = input("Enter your name: ")
print("Hi", name)
# Out:
# Enter your name:  jupyter
# Hi jupyter

# %%
score = int(input("Enter your score: "))
print("My Score is:", score)
# Out:
# Enter your score:  99
# My Score is: 99

# %%
# f string
age = 48
type(age)
year = 1978
x = f"I am {age} years old, born in {year}"
print(x)
# Out:
# I am 48 years old, born in 1978

# %%
#.format()
language = "python"
subject = 'Artificial Intelligence'
print("I like {},my subject is {}".format(language,subject))
# Out:
# I like python,my subject is Artificial Intelligence

# %% [markdown]
# Boolean Evaluation

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True is True
# Out:
# True

# %%
True is False
# Out:
# False

# %%
'a' is 'a'
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\8avin\AppData\Local\Temp\ipykernel_9656\4112465208.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   'a' is 'a'
# True

# %%
'a' == 'a'
# Out:
# True

# %% [markdown]
# Branching(if/elif/else)

# %%
i = int(input("Enter the name:"))
if(i<3):
    if i<=2:
        print('Less than 2')
    else:
        print('Less than 3')
elif i<5:
    print('Less than 5')
elif i<12:
    print('I am stupid')
else:
    print('5 or more')
# Out:
# Enter the name: 4
# Less than 5

# %%
x = 'Jupyter'
for i in x:
    if i=='e':
        continue
    print(i)
# Out:
# J
# u
# p
# y
# t
# r

# %%
x = 'Jupyter'
for i in x:
    print(i)
# Out:
# J
# u
# p
# y
# t
# e
# r

# %%
1 == '1'
# Out:
# False
